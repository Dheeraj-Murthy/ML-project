# %% [markdown]
# # Model Execution Report

# %% [markdown]
# ## Running model_adaboost

# %%
# !python Adaboost/model_adaboost.py
# Out:
# python: can't open file 'Adaboost/model_adaboost.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Running model_catboost

# %%
# !python catboost/model_catboost.py
# Out:
# python: can't open file 'catboost/model_catboost.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Running model_full_linear

# %%
# !python Linear_Regression/model_full_linear.py
# Out:
# python: can't open file 'Linear_Regression/model_full_linear.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Running Polynomial Regression

# %%
# !python PolyRegression/poly_model.py
# Out:
# python: can't open file 'PolyRegression/poly_model.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Running model_random_forest

# %%
# !python Random_Forest/model_random_forest.py
# Out:
# python: can't open file 'Random_Forest/model_random_forest.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Running model_regularized_least_square_Lasso

# %%
# !python Regularized_Linear_Regression/model_regularized_least_square_Lasso.py
# Out:
# python: can't open file 'Regularized_Linear_Regression/model_regularized_least_square_Lasso.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Running model_regularized_least_square_Ridge

# %%
# !python Regularized_Linear_Regression/model_regularized_least_square_Ridge.py
# Out:
# python: can't open file 'Regularized_Linear_Regression/model_regularized_least_square_Ridge.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Running model_regularized_least_squares_ElasticNet

# %%
# !python Regularized_Linear_Regression/model_regularized_least_squares_ElasticNet.py
# Out:
# python: can't open file 'Regularized_Linear_Regression/model_regularized_least_squares_ElasticNet.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Running model_xgboost

# %%
# !python XGboost/xgboost_model.py
# Out:
# python: can't open file 'XGboost/xgboost_model.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Running model_gaussian

# %%
# !python model_gaussian.py
# Out:
# python: can't open file 'model_gaussian.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Running Bayesian_model

# %%
# !python Bayesian/bayesian_model.py
# Out:
# python: can't open file 'Bayesian/bayesian_model.py': [Errno 2] No such file or directory

# %% [markdown]
# ## Running model_lightgbm

# %%
# !python model_lightgbm.py
# Out:
# python: can't open file 'model_lightgbm.py': [Errno 2] No such file or directory

# %%
# !cat results.csv
# Out:
# cat: results.csv: No such file or directory
